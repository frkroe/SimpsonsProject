# %% [markdown]
# # The Simpsons (Bart Level)

# %%
# leer archivo cuantas.csv de Lisa y guardar las 10 palabras más usadas y plotearlas
import pandas as pd
df = pd.read_csv(r'C:\Users\franz\Documents\GitHub\SimpsonsProject\Project2Lisa\app\cuentas.csv', delimiter=",")
dfSorted= df.sort_values(by=['Cuenta'],ascending=False)
#print(dfSorted)
top10 = dfSorted.nlargest(10,'Cuenta')
#print(top10)
top10.plot(x='Palabra', y='Cuenta', kind='bar')
# Out:
# <AxesSubplot: xlabel='Palabra'>
# C:\Users\franz\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\IPython\core\pylabtools.py:151: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#plotear 
from IPython.display import Image, display
Image(r"\Users\franz\Documents\GitHub\SimpsonsProject\Project2Lisa\app\Dr_Nick\Dr_Nick.png")
